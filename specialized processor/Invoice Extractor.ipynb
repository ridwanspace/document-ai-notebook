# %% [markdown]
# ## Invoice Extraction using Document AI and Python
#
# In this tutorial, we will use Document AI's specialized processor (Invoice Parser). For learning purpose, we use example cards available in Google search.
#
# We will follow this [official documentation](https://cloud.google.com/document-ai/docs/processors-list#specialized_processors) as reference.

# %% [markdown]
# #### 1. Setup Environment

# %%
import os
import json
from google.cloud import documentai_v1 as documentai
from google.oauth2 import service_account
from mimetypes import guess_type
from dotenv import load_dotenv
import PIL.Image
import pandas as pd

# %%
load_dotenv()
project_id = os.environ['PROJECT_ID']
location = os.environ['REGION']
processor_id = os.environ['INVOICE_PROCESSOR_ID']

# %%
service_account_path = '../norse.json' # change this path
credentials = service_account.Credentials.from_service_account_file(service_account_path)

# %% [markdown]
# #### 2. Create Extraction Function

# %%
def online_process(
    project_id: str,
    location: str,
    processor_id: str,
    file_path: str,
    file_name: str,
) -> documentai.Document:
    """
    Processes a document using the Document AI Online Processing API.
    """

    opts = {"api_endpoint": f"{location}-documentai.googleapis.com"}

    # Instantiates a client by passing credentials and the API endpoint
    documentai_client = documentai.DocumentProcessorServiceClient(client_options=opts, credentials=credentials)

    # The full resource name of the processor, e.g.:
    # projects/project-id/locations/location/processor/processor-id
    # You must create new processors in the Cloud Console first
    resource_name = documentai_client.processor_path(project_id, location, processor_id)

    # Read the file into memory
    with open(file_path, "rb") as file:
        file_content = file.read()

    # Guess the MIME type based on the file name
    mime_type, _ = guess_type(file_name)
    if mime_type is None:
        raise ValueError("Unable to determine the file's MIME type")

    # Load Binary Data into Document AI RawDocument Object
    raw_document = documentai.RawDocument(content=file_content, mime_type=mime_type)

    # Configure the process request
    request = documentai.ProcessRequest(name=resource_name, raw_document=raw_document)

    # Use the Document AI client to process the sample form
    result = documentai_client.process_document(request=request)

    entities = result.document.entities

    return entities

# %% [markdown]
# #### 3. Run The Extraction
#
# ##### Example A

# %%
# load example id card
file_path = './examples/invoice1.jpg'
# Extract file name from file path
file_name = os.path.basename(file_path)

PIL.Image.open(file_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1275x1650>

# %%
response = online_process(project_id, location, processor_id, file_path, file_name)

# %%
# Extract and display information from the document
types = []
raw_values = []
normalized_values = []
confidence = []

for entity in response:
    types.append(entity.type)
    raw_values.append(entity.mention_text)
    normalized_values.append(entity.normalized_value.text)
    confidence.append(f"{entity.confidence:.0%}")

    for prop in entity.properties:
        types.append(prop.type_)
        raw_values.append(prop.mention_text)
        normalized_values.append(prop.normalized_value.text)
        confidence.append(f"{prop.confidence:.0%}")

df = pd.DataFrame(
    {
        "Type": types,
        "Raw Value": raw_values,
        "Normalized Value": normalized_values,
        "Confidence": confidence,
    }
)
df
# Out:
#                      Type                                         Raw Value  \
# 0                due_date                                      Sep 30, 2019
# 1              net_amount                                         22,379.39
# 2            invoice_date                                      Sep 24, 2019
# 3            total_amount                                         19,647.68
# 4        total_tax_amount                                          1,767.97
# 5           receiver_name                                       Jane Smith,
# 6              invoice_id                                         23413561D
# 7            invoice_type
# 8        receiver_address  1600 Amphitheatre Pkway\nMountain View, CA 94043
# 9          freight_amount                                            199.99
# 10          supplier_name                                            Google
# 11              line_item                   12 9.99 119.88 12 ft HDMI cable
# 12     line_item/quantity                                                12
# 13   line_item/unit_price                                              9.99
# 14       line_item/amount                                            119.88
# 15  line_item/description                                  12 ft HDMI cable
# 16              line_item           12 399.99 4,799.88 27" Computer Monitor
# 17     line_item/quantity                                                12
# 18   line_item/unit_price                                            399.99
# 19       line_item/amount                                          4,799.88
# 20  line_item/description                              27" Computer Monitor
# 21              line_item                12 59.99 719.88 Ergonomic Keyboard
# 22     line_item/quantity                                                12
# 23   line_item/unit_price                                             59.99
# 24       line_item/amount                                            719.88
# 25  line_item/description                                Ergonomic Keyboard
# 26              line_item                     Optical mouse 12 19.99 239.88
# 27  line_item/description                                     Optical mouse
# 28     line_item/quantity                                                12
# 29   line_item/unit_price                                             19.99
# 30       line_item/amount                                            239.88
# 31              line_item                      Laptop 12 1,299.99 15,599.88
# 32  line_item/description                                            Laptop
# 33     line_item/quantity                                                12
# 34   line_item/unit_price                                          1,299.99
# 35       line_item/amount                                         15,599.88
# 36              line_item              Misc processing fees 899.99 1 899.99
# 37  line_item/description                              Misc processing fees
# 38       line_item/amount                                            899.99
# 39     line_item/quantity                                                 1
# 40   line_item/unit_price                                            899.99
#
#      Normalized Value Confidence
# 0          2019-09-30        99%
# 1            22379.39        99%
# 2          2019-09-24        98%
# 3            19647.68        97%
# 4             1767.97        94%
# 5                            87%
# 6                            84%
# 7   invoice_statement        80%
# 8                            76%
# 9              199.99        60%
# 10             Google         7%
# 11                          100%
# 12                 12        79%
# 13               9.99        95%
# 14             119.88        91%
# 15                           55%
# 16                          100%
# 17                 12        80%
# 18             399.99        94%
# 19            4799.88        93%
# 20                           40%
# 21                          100%
# 22                 12        75%
# 23              59.99        94%
# 24             719.88        89%
# 25                           39%
# 26                          100%
# 27                           43%
# 28                 12        77%
# 29              19.99        94%
# 30             239.88        89%
# 31                          100%
# 32                           53%
# 33                 12        74%
# 34            1299.99        92%
# 35           15599.88        93%
# 36                          100%
# 37                           47%
# 38             899.99        85%
# 39                  1        72%
# 40             899.99        91%

# %% [markdown]
# ##### Example B

# %%
# load example id card
file_path = './examples/invoice2.jpg'
# Extract file name from file path
file_name = os.path.basename(file_path)

PIL.Image.open(file_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=724x1024>

# %%
response = online_process(project_id, location, processor_id, file_path, file_name)

# %%
# Extract and display information from the document
types = []
raw_values = []
normalized_values = []
confidence = []

for entity in response:
    types.append(entity.type)
    raw_values.append(entity.mention_text)
    normalized_values.append(entity.normalized_value.text)
    confidence.append(f"{entity.confidence:.0%}")

    for prop in entity.properties:
        types.append(prop.type_)
        raw_values.append(prop.mention_text)
        normalized_values.append(prop.normalized_value.text)
        confidence.append(f"{prop.confidence:.0%}")

df = pd.DataFrame(
    {
        "Type": types,
        "Raw Value": raw_values,
        "Normalized Value": normalized_values,
        "Confidence": confidence,
    }
)
df
# Out:
#                      Type                          Raw Value  \
# 0            total_amount                            880,000
# 1              net_amount                            800,000
# 2                currency                                 RP
# 3           supplier_name  SALFORD & CO.\nFashion Terlengkap
# 4          supplier_phone                      +123-456-7890
# 5        total_tax_amount                             80,000
# 6            invoice_date                        128/03/2022
# 7            invoice_type
# 8          receiver_email          hello@reallygreatsite.com
# 9           receiver_name                       Ketut Susilo
# 10              line_item               100,000 1 RP 100,000
# 11     line_item/quantity                            100,000
# 12     line_item/quantity                                  1
# 13         line_item/unit                                 RP
# 14       line_item/amount                            100,000
# 15              line_item               200,000 1 RP 200,000
# 16     line_item/quantity                            200,000
# 17     line_item/quantity                                  1
# 18         line_item/unit                                 RP
# 19       line_item/amount                            200,000
# 20              line_item  KAOS POLO RP 120,000 1 RP 120,000
# 21  line_item/description                          KAOS POLO
# 22         line_item/unit                                 RP
# 23     line_item/quantity                            120,000
# 24     line_item/quantity                                  1
# 25         line_item/unit                                 RP
# 26       line_item/amount                            120,000
# 27              line_item                  230,000 1 230,000
# 28     line_item/quantity                            230,000
# 29     line_item/quantity                                  1
# 30       line_item/amount                            230,000
# 31              line_item                  100,000 1 100,000
# 32     line_item/quantity                            100,000
# 33     line_item/quantity                                  1
# 34       line_item/amount                            100,000
#
#      Normalized Value Confidence
# 0                            98%
# 1                            93%
# 2                            90%
# 3                            62%
# 4                            62%
# 5                            61%
# 6                            50%
# 7   invoice_statement        48%
# 8                            46%
# 9                            39%
# 10                          100%
# 11                           15%
# 12                  1        72%
# 13                           31%
# 14                           84%
# 15                          100%
# 16                           26%
# 17                  1        64%
# 18                           20%
# 19                           90%
# 20                          100%
# 21                           54%
# 22                           13%
# 23                           27%
# 24                  1        64%
# 25                           12%
# 26                           88%
# 27                          100%
# 28                           12%
# 29                  1        60%
# 30                           84%
# 31                          100%
# 32                           37%
# 33                  1        63%
# 34                           77%
