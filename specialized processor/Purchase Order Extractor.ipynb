# %% [markdown]
# ## Purchase Order Extraction using Document AI and Python
#
# In this tutorial, we will use Document AI's specialized processor (Purchase Order Parser). For learning purpose, we use example cards available in Google search.
#
# We will follow this [official documentation](https://cloud.google.com/document-ai/docs/processors-list#specialized_processors) as reference.

# %% [markdown]
# #### 1. Setup Environment

# %%
import os
import json
from google.cloud import documentai_v1 as documentai
from google.oauth2 import service_account
from mimetypes import guess_type
from dotenv import load_dotenv
import PIL.Image
import pandas as pd

# %%
load_dotenv()
project_id = os.environ['PROJECT_ID']
location = os.environ['REGION']
processor_id = os.environ['PO_PROCESSOR_ID']

# %%
service_account_path = '../norse.json' # change this path
credentials = service_account.Credentials.from_service_account_file(service_account_path)

# %% [markdown]
# #### 2. Create Extraction Function

# %%
def online_process(
    project_id: str,
    location: str,
    processor_id: str,
    file_path: str,
    file_name: str,
) -> documentai.Document:
    """
    Processes a document using the Document AI Online Processing API.
    """

    opts = {"api_endpoint": f"{location}-documentai.googleapis.com"}

    # Instantiates a client by passing credentials and the API endpoint
    documentai_client = documentai.DocumentProcessorServiceClient(client_options=opts, credentials=credentials)

    # The full resource name of the processor, e.g.:
    # projects/project-id/locations/location/processor/processor-id
    # You must create new processors in the Cloud Console first
    resource_name = documentai_client.processor_path(project_id, location, processor_id)

    # Read the file into memory
    with open(file_path, "rb") as file:
        file_content = file.read()

    # Guess the MIME type based on the file name
    mime_type, _ = guess_type(file_name)
    if mime_type is None:
        raise ValueError("Unable to determine the file's MIME type")

    # Load Binary Data into Document AI RawDocument Object
    raw_document = documentai.RawDocument(content=file_content, mime_type=mime_type)

    # Configure the process request
    request = documentai.ProcessRequest(name=resource_name, raw_document=raw_document)

    # Use the Document AI client to process the sample form
    result = documentai_client.process_document(request=request)

    entities = result.document.entities

    return entities

# %% [markdown]
# #### 3. Run The Extraction
#
# ##### Example A

# %%
# load example id card
file_path = './examples/po1.png'
# Extract file name from file path
file_name = os.path.basename(file_path)

PIL.Image.open(file_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1354x1536>

# %%
response = online_process(project_id, location, processor_id, file_path, file_name)

# %%
# Extract and display information from the document
types = []
raw_values = []
normalized_values = []
confidence = []

for entity in response:
    types.append(entity.type)
    raw_values.append(entity.mention_text)
    normalized_values.append(entity.normalized_value.text)
    confidence.append(f"{entity.confidence:.0%}")

    for prop in entity.properties:
        types.append(prop.type_)
        raw_values.append(prop.mention_text)
        normalized_values.append(prop.normalized_value.text)
        confidence.append(f"{prop.confidence:.0%}")

df = pd.DataFrame(
    {
        "Type": types,
        "Raw Value": raw_values,
        "Normalized Value": normalized_values,
        "Confidence": confidence,
    }
)
df
# Out:
#                             Type  \
# 0                       currency
# 1              purchase_order_id
# 2            purchase_order_date
# 3                   total_amount
# 4                   ship_to_name
# 5                  receiver_name
# 6                  payment_terms
# 7                  delivery_date
# 8                      line_item
# 9          line_item/description
# 10  line_item/receiver_reference
# 11            line_item/quantity
# 12              line_item/amount
# 13                     line_item
# 14         line_item/description
# 15            line_item/quantity
# 16              line_item/amount
# 17                     line_item
# 18         line_item/description
# 19        line_item/product_code
# 20                     line_item
# 21        line_item/product_code
# 22              line_item/amount
# 23                     line_item
# 24         line_item/description
# 25                     line_item
# 26         line_item/description
# 27        line_item/product_code
# 28                     line_item
# 29        line_item/product_code
# 30          line_item/unit_price
# 31          line_item/unit_price
# 32              line_item/amount
#
#                                             Raw Value Normalized Value  \
# 0                                                   $              USD
# 1                                             PO00495
# 2                                          04/26/2017       2017-04-26
# 3                                              228.47           228.47
# 4                                       Boston Office
# 5                                       Boston Office
# 6                                             30 Days
# 7                                          04/28/2017       2017-04-28
# 8   Nescafe Gold Blend Coffee 7oz QD2-00350 1.00 3...
# 9                       Nescafe Gold Blend Coffee 7oz
# 10                                          QD2-00350
# 11                                               1.00                1
# 12                                              34.99            34.99
# 13       Tettley Tea Round Tea Bags 440/Pk 1.00 20.49
# 14                  Tettley Tea Round Tea Bags 440/Pk
# 15                                               1.00                1
# 16                                              20.49            20.49
# 17  Niceday Economy Lever Arch File A4 Black 81-48...
# 18           Niceday Economy Lever Arch File A4 Black
# 19                                         81-4857579
# 20                                      1523055 71.67
# 21                                            1523055
# 22                                              71.67            71.67
# 23                           Viking A4 Economy Copier
# 24                           Viking A4 Economy Copier
# 25          Economy Manilla Envelopes - 500 2-2071074
# 26                    Economy Manilla Envelopes - 500
# 27                                          2-2071074
# 28                          -1523055 23.89 0.00 23.89
# 29                                           -1523055
# 30                                              23.89            23.89
# 31                                               0.00                0
# 32                                              23.89            23.89
#
#    Confidence
# 0         96%
# 1         94%
# 2         93%
# 3         80%
# 4         73%
# 5         69%
# 6         66%
# 7         35%
# 8        100%
# 9         73%
# 10        59%
# 11        71%
# 12        73%
# 13       100%
# 14        81%
# 15        81%
# 16        61%
# 17       100%
# 18        77%
# 19         1%
# 20       100%
# 21         5%
# 22        37%
# 23       100%
# 24        79%
# 25       100%
# 26        53%
# 27         3%
# 28       100%
# 29         1%
# 30        78%
# 31        45%
# 32        40%

# %% [markdown]
# ##### Example B

# %%
# load example id card
file_path = './examples/po2.png'
# Extract file name from file path
file_name = os.path.basename(file_path)

PIL.Image.open(file_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1632x2112>

# %%
response = online_process(project_id, location, processor_id, file_path, file_name)

# %%
# Extract and display information from the document
types = []
raw_values = []
normalized_values = []
confidence = []

for entity in response:
    types.append(entity.type)
    raw_values.append(entity.mention_text)
    normalized_values.append(entity.normalized_value.text)
    confidence.append(f"{entity.confidence:.0%}")

    for prop in entity.properties:
        types.append(prop.type_)
        raw_values.append(prop.mention_text)
        normalized_values.append(prop.normalized_value.text)
        confidence.append(f"{prop.confidence:.0%}")

df = pd.DataFrame(
    {
        "Type": types,
        "Raw Value": raw_values,
        "Normalized Value": normalized_values,
        "Confidence": confidence,
    }
)
df
# Out:
#                      Type                                          Raw Value  \
# 0     purchase_order_date                                         04/06/2022
# 1                currency                                                  $
# 2           payment_terms                                        Net 30 Days
# 3            total_amount                                            1087.28
# 4           delivery_date                                         04/06/2022
# 5       purchase_order_id                                              #1742
# 6         ship_to_address                                       360 Footwear
# 7               line_item  Pursuit Running Shoes Men's Pursuit Running Sh...
# 8   line_item/description                              Pursuit Running Shoes
# 9   line_item/description                 Men's Pursuit Running Shoes - 10/M
# 10     line_item/quantity                                                 10
# 11   line_item/unit_price                                              59.50
# 12       line_item/amount                                             595.00
# 13              line_item  Shelby Boots Men's Shelby Leather Boots - 10/M...
# 14  line_item/description                                       Shelby Boots
# 15  line_item/description                  Men's Shelby Leather Boots - 10/M
# 16     line_item/quantity                                                 10
# 17   line_item/unit_price                                              39.50
# 18       line_item/amount                                             395.00
# 19              line_item                                              37.88
# 20       line_item/amount                                              37.88
#
#    Normalized Value Confidence
# 0        2022-04-06        98%
# 1               USD        93%
# 2                          91%
# 3           1087.28        87%
# 4        2022-04-06        67%
# 5                          59%
# 6                          28%
# 7                         100%
# 8                          50%
# 9                          59%
# 10               10        95%
# 11             59.5        85%
# 12              595        97%
# 13                        100%
# 14                         61%
# 15                         72%
# 16               10        95%
# 17             39.5        64%
# 18              395        98%
# 19                        100%
# 20            37.88        48%
